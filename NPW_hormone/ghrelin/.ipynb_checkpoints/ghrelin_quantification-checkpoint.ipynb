# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ghrelin.csv')
standard = pd.read_csv('standard.csv')

# %%
sns.set(font_scale=2) 
sns.set_style("ticks")
plt.subplots(figsize= (2,2))
sns.swarmplot(x = 'state', y = 'Abundance', data = df[df.status == 'second'], palette = ['Tab:blue', 'red', 'gray'])
sns.boxplot(x = 'state', y = 'Abundance', data = df[df.status == 'second'],  boxprops=dict(alpha=.5), palette = ['Tab:blue', 'red', 'gray'],width = 0.5)
sns.despine()
plt.xticks(rotation = 90)
plt.savefig('ghrelin.png', dpi = 300,  bbox_inches='tight' )

# %%
standard.amount
# Out:
# 0     1
# 1     5
# 2    10
# 3    20
# 4    50
# 5    75
# Name: amount, dtype: int64

# %%
plt.subplots(figsize= (5,2))
sns.lineplot(x = 'abundance', y = 'amount', data = standard)
sns.despine()
